# %% [markdown]
# # Impact Context Reduction
#
# This notebook server to select the tasks and prepare the dataset to be used for the experiment

# %%
import pandas as pd
import plotly.express as px
import random
from sentence_transformers import SentenceTransformer
import torch

random.seed(42)

# %% [markdown]
# ## Load and Select
#
# The data from Instruction Induction is loaded and then it's selected the tasks with unique response value

# %%
folder = "../../data/instruction-induction-data/raw"
tasks_df = pd.read_csv(f"{folder}/induce_tasks_examples.csv")

# %%
tasks_df
# Out:
#                     task                                              input  \
# 0      active_to_passive                 The tourist supported the authors.
# 1      active_to_passive                The athlete contacted the tourists.
# 2      active_to_passive                   The judges believed the bankers.
# 3      active_to_passive                The president encouraged the actor.
# 4      active_to_passive                  The lawyers believed the authors.
# ...                  ...                                                ...
# 67640    word_in_context  Sentence 1: I know the feeling! Sentence 2: Ha...
# 67641    word_in_context  Sentence 1: Confidence is always borrowed, nev...
# 67642    word_in_context  Sentence 1: Messages must go through diplomati...
# 67643    word_in_context  Sentence 1: The end of the year. Sentence 2: O...
# 67644    word_in_context  Sentence 1: Emotion caused a constriction of h...
#
#                                             output  \
# 0       The authors were supported by the tourist.
# 1      The tourists were contacted by the athlete.
# 2         The bankers were believed by the judges.
# 3       The actor was encouraged by the president.
# 4        The authors were believed by the lawyers.
# ...                                            ...
# 67640                                         same
# 67641                                 not the same
# 67642                                 not the same
# 67643                                 not the same
# 67644                                         same
#
#                       possible_outputs
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 67640          ['same', 'yes', 'true']
# 67641  ['not the same', 'no', 'false']
# 67642  ['not the same', 'no', 'false']
# 67643  ['not the same', 'no', 'false']
# 67644          ['same', 'yes', 'true']
#
# [67645 rows x 4 columns]

# %%
tasks_df["task"].unique()
# Out:
# array(['active_to_passive', 'antonyms', 'cause_and_effect', 'diff',
#        'first_word_letter', 'informal_to_formal', 'larger_animal',
#        'letters_list', 'negation', 'num_to_verbal',
#        'orthography_starts_with', 'rhymes', 'second_word_letter',
#        'sentence_similarity', 'sentiment', 'singular_to_plural', 'sum',
#        'synonyms', 'taxonomy_animal', 'translation_en-de',
#        'translation_en-es', 'translation_en-fr', 'word_in_context'],
#       dtype=object)

# %%
selected_tasks_list = ['active_to_passive', 'antonyms', 'diff', 'first_word_letter',
        'larger_animal', 'letters_list', 'negation',
       'num_to_verbal', 'orthography_starts_with', 'rhymes',
       'second_word_letter', 'sentence_similarity', 'sentiment',
       'singular_to_plural', 'sum', 'synonyms', 'taxonomy_animal',
       'translation_en-de', 'translation_en-es', 'translation_en-fr',
       'word_in_context']

selected_tasks = tasks_df[tasks_df["task"].isin(selected_tasks_list)]

# %%
## Select tasks for test set
ex_tasks_df = pd.read_csv(f"{folder}/execute_tasks_examples.csv")
test = ex_tasks_df[ex_tasks_df["task"].isin(selected_tasks_list)]

# %% [markdown]
# ## Plot distribuition of samples

# %%
fig = px.histogram(selected_tasks, x="task", title="Induce Tasks Count")
fig.show()

# %%
fig = px.histogram(test, x="task", title="Induce Tasks Count")
fig.show()

# %% [markdown]
# ## Undersampling the pool of tasks
#
# In order to avoid class unbalancement to select the examples we will create a upper limit of 900 examples per classs
# They will be randomly selected

# %%
test
# Out:
#                    task                                              input  \
# 0     active_to_passive                The professor mentioned the artist.
# 1     active_to_passive             The presidents recommended the lawyer.
# 2     active_to_passive               The professors thanked the tourists.
# 3     active_to_passive                 The scientist contacted the judge.
# 4     active_to_passive                   The doctor stopped the managers.
# ...                 ...                                                ...
# 2135    word_in_context  Sentence 1: He put the cup back in the saucer....
# 2136    word_in_context  Sentence 1: His treatment of the race question...
# 2137    word_in_context  Sentence 1: Please bracket this remark. Senten...
# 2138    word_in_context  Sentence 1: Violate the sanctity of the church...
# 2139    word_in_context  Sentence 1: I appreciate your efforts. Sentenc...
#
#                                              output  \
# 0        The artist was mentioned by the professor.
# 1     The lawyer was recommended by the presidents.
# 2      The tourists were thanked by the professors.
# 3         The judge was contacted by the scientist.
# 4          The managers were stopped by the doctor.
# ...                                             ...
# 2135                                           same
# 2136                                   not the same
# 2137                                   not the same
# 2138                                   not the same
# 2139                                   not the same
#
#                      possible_outputs
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 2135          ['same', 'yes', 'true']
# 2136  ['not the same', 'no', 'false']
# 2137  ['not the same', 'no', 'false']
# 2138  ['not the same', 'no', 'false']
# 2139  ['not the same', 'no', 'false']
#
# [2100 rows x 4 columns]

# %%
def get_random_sample_per_category(df: pd.DataFrame, n_samples_per_category: int = 900) -> pd.DataFrame:
  
    """
    Returns a sampled DataFrame with a specified number of rows per category.

    Args:
    df (pd.DataFrame): The input DataFrame to be sampled.
    num_samples (int): The number of rows to sample per category.

    Returns:
    pd.DataFrame: The sampled DataFrame.

    Notes:
    - If a category has fewer rows than the specified number of samples, all rows in that category are included in the sample.
    - If a category has more rows than the specified number of samples, a random sample of the specified number of rows is returned.
    - If a category has exactly the specified number of rows, all rows in that category are included in the sample.
    - If a category has less than the specified number of rows, a warning message is printed.

    Example:
    >>> df = pd.DataFrame({'task': ['A', 'B', 'A', 'B', 'C', 'C'], 'value': [1, 2, 3, 4, 5, 6]})
    >>> get_random_sample_per_category(df, 2)
    task  value
    0     A      1
    2     A      3
    1     B      2
    3     B      4
    4     C      5
    5     C      6
    """

    # Group the DataFrame by the "task" column
    grouped_df = df.groupby('task')

    # Create an empty DataFrame to store the results
    sampled_df = pd.DataFrame()

    # Iterate through each group and randomly sample n_samples_per_category rows
    for name, group in grouped_df:
        if len(group) >= n_samples_per_category:  # Check if there are enough rows in the group
            sampled_df = pd.concat([sampled_df, group.sample(n_samples_per_category, random_state=42)])
        else:
            print(f"Warning: Category '{name}' has less than {n_samples_per_category} rows. All rows included.")
            sampled_df = pd.concat([sampled_df, group])

    return sampled_df

# %%
#undersampling the examples
sampled_df = get_random_sample_per_category(selected_tasks, 900)
fig = px.histogram(sampled_df, x="task", title="Induce Tasks Count")
fig.show()

# %% [markdown]
# ## Creating Embeddings

# %%
model = SentenceTransformer('sentence-transformers/stsb-roberta-large')
# Out:
# c:\Users\caior\OneDrive\Documentos\GitHub\datamodels-context-reduction\venv\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning:
#
# `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.

# %%
with torch.no_grad():
    test["input_encoding"] = list(model.encode(test["input"].tolist()))
    test["output_encoding"] = list(model.encode(test["output"].tolist()))
    sampled_df["input_encoding"] = list(model.encode(sampled_df["input"].tolist()))
    sampled_df["output_encoding"] = list(model.encode(sampled_df["output"].tolist()))
# Out:
# C:\Users\caior\AppData\Local\Temp\ipykernel_23404\2061887857.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\caior\AppData\Local\Temp\ipykernel_23404\2061887857.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test.head()
# Out:
#                 task                                   input  \
# 0  active_to_passive     The professor mentioned the artist.
# 1  active_to_passive  The presidents recommended the lawyer.
# 2  active_to_passive    The professors thanked the tourists.
# 3  active_to_passive      The scientist contacted the judge.
# 4  active_to_passive        The doctor stopped the managers.
#
#                                           output possible_outputs  \
# 0     The artist was mentioned by the professor.              NaN
# 1  The lawyer was recommended by the presidents.              NaN
# 2   The tourists were thanked by the professors.              NaN
# 3      The judge was contacted by the scientist.              NaN
# 4       The managers were stopped by the doctor.              NaN
#
#                                       input_encoding  \
# 0  [-0.20012294, 0.13508783, -0.2985632, -0.87351...
# 1  [-0.4970448, 0.4357985, -0.6567291, -0.3953907...
# 2  [-0.3240893, -0.14898217, -1.352726, 0.3582022...
# 3  [0.102656126, 0.30964082, -0.1751958, -0.03980...
# 4  [-1.1253037, -0.44782987, -0.21806452, 0.75703...
#
#                                      output_encoding
# 0  [-0.09183042, -0.04686316, -0.33048978, -1.268...
# 1  [-0.66726875, 0.34483844, -0.8113683, -1.00565...
# 2  [-0.323816, -0.33156234, -1.244837, 0.34510475...
# 3  [0.2995165, 0.50604427, -0.22411016, -0.802559...
# 4  [-0.73601687, -0.23098752, -0.51134634, 0.3905...

# %%
sampled_df.head()
# Out:
#                   task                                     input  \
# 70   active_to_passive       The lawyer avoided the secretaries.
# 827  active_to_passive      The judges supported the scientists.
# 231  active_to_passive  The secretary recommended the professor.
# 588  active_to_passive    The artists recommended the secretary.
# 39   active_to_passive        The secretary avoided the senator.
#
#                                               output possible_outputs  \
# 70       The secretaries were avoided by the lawyer.              NaN
# 827     The scientists were supported by the judges.              NaN
# 231  The professor was recommended by the secretary.              NaN
# 588    The secretary was recommended by the artists.              NaN
# 39         The senator was avoided by the secretary.              NaN
#
#                                         input_encoding  \
# 70   [-0.24385086, -0.64486957, -0.64685297, -0.420...
# 827  [-0.5501171, 0.6825413, -0.9810991, -0.5485433...
# 231  [-0.0900043, -0.7063172, -0.6908893, -0.936058...
# 588  [-0.68770576, -0.63871086, -0.1755478, -0.7951...
# 39   [-0.15601312, 0.07417155, -0.52595055, -0.6627...
#
#                                        output_encoding
# 70   [-0.28393745, -0.95630246, -0.746785, -0.78612...
# 827  [-0.56822073, 0.5160339, -1.1946347, -0.480039...
# 231  [-0.015668165, -0.70485973, -0.8372537, -0.885...
# 588  [-0.5098828, -0.47384205, -0.53428304, -1.1165...
# 39   [-0.25937113, -0.28749138, -0.81921023, -0.821...

# %% [markdown]
# ## Save the .csv files to final dataframes

# %%
# save csvs
test.to_pickle("test.pickle")
sampled_df.to_pickle("pool.pickle")
